# %% [markdown]
# # Subscriber
# **Run this for being a Subscriber**
# Subscribe to **topic: "CPE_HOUSE/room1"**
#
# Clients can subscribe to the exact topic of a published message or use wildcards to subscribe to multiple topics at the same time <br>
# A wildcard can only be used to subscribe to topics, not to publish a message

# %% [markdown]
# Test publish from this site:
# https://www.hivemq.com/demos/websocket-client/
#
# and run code below for see the result

# %%
import paho.mqtt.client as mqtt
MQTT_HOST = "broker.mqttdashboard.com"
MQTT_PORT = 1883
MQTT_KEEPALIVE_INTERVAL = 45 #45 seconds
MQTT_TOPIC = "CPE_DEMO_HOUSE/#"

def on_connect(self,client, userdata, rc):
    print("MQTT Connected.")
    self.subscribe(MQTT_TOPIC)
    # add more subscribe ...
    # e.g.;
    # self.subscribe("CPE_DEMO_HOUSE/room2/#")

def on_message(client, userdata, msg):
    print("message received...")
    print(msg.topic + " "+ str(msg.qos) + " " + str(msg.payload.decode("utf-8","strict")))

client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message
client.connect(MQTT_HOST)
client.loop_forever()
# Out:
# <ipython-input-1-dd26a7d7b7f9>:18: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client()
# MQTT Connected.
# message received...
# CPE_DEMO_HOUSE/room2 0 {"Temperature": 35, "Humidity": 60, "Light": 138}
# message received...
# CPE_DEMO_HOUSE/room1 0 {"Temperature": 35, "Humidity": 60, "Light": 138}
# message received...
# CPE_DEMO_HOUSE/room1 0 Hello World!
# message received...
# CPE_DEMO_HOUSE/room1 0 Hello World!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-dd26a7d7b7f9> in <module>
#      20 client.on_message = on_message
#      21 client.connect(MQTT_HOST)
# ---> 22 client.loop_forever()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/paho/mqtt/client.py in loop_forever(self, timeout, retry_first_connection)
#    2295             rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296             while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297                 rc = self._loop(timeout)
#    2298                 # We don't need to worry about locking here, because we've
#    2299                 # either called loop_forever() when in single threaded mode, or
#
# ~/opt/anaconda3/lib/python3.8/site-packages/paho/mqtt/client.py in _loop(self, timeout)
#    1661
#    1662         try:
# -> 1663             socklist = select.select(rlist, wlist, [], timeout)
#    1664         except TypeError:
#    1665             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:
